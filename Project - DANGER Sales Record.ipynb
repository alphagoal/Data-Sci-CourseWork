# %% [markdown]
# ## Project - DANGER Sales Record

# %% [markdown]
# The cashier of DANGER restaurant stores all the sales he received in a database.
#
#
#
# He kept track on the name, sales amount, food eaten and the date of every customer.
#
#
#
# However, one day the database broken, and the string below is the only thing that he was able to recover.
#
#
#
# Let's turn it into a more usable data format!

# %% [markdown]
# 1. Run below code first to save the record into variable named `daily_sales`

# %%
daily_sales = '''

Jaime Buchanan   ;,;$1.2   ;,;   egg ;,; \n25/04/2020   ,

Herbert Tran   ;,;   $7.2;,; \negg&ham;,;   25/04/2020 ,

Paul Clarke ;,;$12.5 \n;,;   egg&ham ;,;  25/04/2020 ,



Lucille Caldwell   \n;,;   $5.1   ;,; egg   ;,; 25/04/2020,\nEduardo George

;,;$20.3;,; egg&sausage \n;,;25/04/2020   ,   Danny Mclaughlin;,;$30.8;,;

\nmilk ;,;25/04/2020 ,Stacy Vargas;,; $1.8   ;,; \nmilk&sausage ;,;25/04/2020,

Shaun Brock;,; \n$17.9;,;milk&sausage ;,; 25/04/2020 , \nErick Harper ;,;$17.4;,;

ham ;,; 25/04/2020, \nMichelle Howell ;,;$28.5;,; ham;,;   25/04/2020

, \nCarroll Boyd;,; $14.5;,;   milk&ham   ;,;   \n25/04/2020   , Teresa Carter

;,; $19.6 ;,; \negg;,;25/04/2020   ,   Jacob Kennedy ;,; $11.4   \n;,; egg&vegetable

;,; 25/04/2020, Craig Chambers;,; \n$8.7 ;,; egg&ham&vegetable   ;,;25/04/2020

, Peggy Bell;,; $8.6 ;,;ham   ;,; 25/04/2020,   Kenneth Cunningham ;,;   $10.5;,;

tea&ham   ;,; \n25/04/2020   ,   Marvin Morgan;,;   $16.4;,; \ntea&ham&vegetable

;,;   25/04/2020 ,Herbert Tran \n;,; $6.5 ;,;   tea&ham&vegetable;,;

25/04/2020 ,\nIsrael Cummings;,;   $11.8   ;,;beans;,;  \n25/04/2020,   June Doyle

;,;   $22.2 ;,;  \nbeans&sausage ;,;25/04/2020 , Jaime Buchanan   ;,;   \n$8.3;,;

egg&beans&sausage   ;,;   25/04/2020,   \nRhonda Farmer;,;$2.9 ;,;   egg&beans&sausage

\n;,;25/04/2020, Darren Mckenzie ;,;$22.9;,;tea \n;,;25/04/2020,Rufus Malone;,;$4.7

;,; tea&sausage \n;,; 25/04/2020   ,Hubert Miles;,;   $3.5   \n;,;tea&sausage&ham;,;

25/04/2020   , Joseph Bridges  ;,;$5.6   ;,; tea&sausage&milk&ham \n;,;   25/04/2020 ,

Ernesto Hunt   ;,;$17.5   ;,;   \nbeans   ;,;   25/04/2020 , Audrey Ferguson ;,; \n$5.5;,;

beans&ham   ;,;25/04/2020 ,Edna Williams ;,; \n$17.1;,; beans&ham;,;   25/04/2020,

Randy Fleming;,;   $21.1 ;,;beans ;,;25/04/2020 ,Elisa Hart;,; $0.3   ;,; beans&milk;,;

25/04/2020   ,\nErnesto Hunt ;,; $13.91   ;,;   beans&milk ;,;   \n25/04/2020,

Shannon Chavez   ;,;$19.2   ;,; \nsausage;,; 25/04/2020   , Sammy Cain;,; $5.4;,;

\nsausage&vegetable ;,;25/04/2020 ,   Steven Reeves ;,;$5.5   \n;,;   sausage;,;

25/04/2020, Ruben Jones   ;,; \n$14.5 ;,;   sausage&ham;,;25/04/2020 , Gail Phelps;,;

$7.3   ;,;   sausage&ham&vegetable\n;,; 25/04/2020   ,   Rene Hardy   ;,; $20.2   ;,;

\nbeans ;,;   25/04/2020 ,   Lucy Snyder   ;,; $8.6   \n;,;beans&vegetable  ;,;

25/04/2020 ,Dallas Obrien ;,;   \n$8.3;,;   beans&vegetable ;,;   25/04/2020,

Stacey Payne \n;,;   $15.7   ;,;   egg&beans&vegetable ;,;25/04/2020   \n,   Tanya Cox

;,;   $6.7   ;,;sausage   ;,; \n25/04/2020 , Melody Moran ;,;   $30.8   \n;,;sausage&beans;,;

25/04/2020 , Kenneth Cunningham   ;,; \n$12.3 ;,; tea&sausage&beans;,;   25/04/2020 ,

\nRyan Webster;,;$2.9 ;,; sausage ;,; 25/04/2020 \n,Justin Blake ;,; $22.4   ;,;

egg&sausage ;,;   \n25/04/2020,   Beverly Baldwin ;,;   $6.6;,;   \negg&sausage&beans

;,;25/04/2020   ,   Dale Brady   \n;,;   $6.2 ;,; sausage   ;,;25/04/2020 ,Guadalupe Potter

;,;$21.1   ;,; sausage;,; 25/04/2020   , \nDesiree Butler ;,;$2.1   ;,;egg;,; 25/04/2020  \n,

Sonja Barnett ;,; $14.2 ;,;egg&beans;,;   \n25/04/2020, Angelica Garza;,;$11.6;,;egg&beans

\n;,;   25/04/2020   ,   Jamie Welch   ;,; $25.2   ;,; \negg&beans&vegetable ;,;25/04/2020   ,

Rex Hudson   \n;,;$8.2;,;   milk;,; 25/04/2020 ,   Nadine Gibbs \n;,;   $30.8 ;,;   milk&sausage

;,; 25/04/2020   , \nHannah Pratt;,;   $22.6   ;,;   milk&sausage   \n;,;25/04/2020,

Gayle Richards;,;$22.19 ;,; \ntea&milk&sausage ;,;25/04/2020   ,Stanley Holland \n;,;

$7.4   ;,; vegetable ;,; 25/04/2020 , Anna Dean;,;$5.4 ;,; sausage&vegetable ;,;   25/04/2020

,\nErnesto Hunt ;,;   $23.7  ;,;tea&sausage&vegetable \n;,; 25/04/2020 ,   Karl Ross

;,; $26.6 ;,; \nvegetable   ;,;25/04/2020 ,Guadalupe Freeman ;,; $25.9;,;

\ntea&vegetable ;,;   25/04/2020   ,Irving Patterson \n;,;$19.5 ;,; tea&egg&vegetable ;,;

25/04/2020 ,Karl Ross;,;   $15.6;,;   egg ;,;   25/04/2020 , Brandy Cortez ;,;$23.5;,;

egg&vegetable   ;,;25/04/2020, \nMamie Riley   ;,;$29.3;,; milk;,;25/04/2020 ,Mike Thornton

;,; $26.4 ;,;   milk   ;,; 25/04/2020, \nJamie Vaughn   ;,; $17.2;,;tea ;,; 25/04/2020

, \nNoah Day ;,;   $8.4   ;,;tea   ;,;25/04/2020   \n,Josephine Keller ;,;$13.1 ;,;tea;,;

25/04/2020 ,   Gail Phelps;,;$20.3 ;,; vegetable   ;,; 25/04/2020 ,\nIgnacio Parks;,;$14.7

;,; egg&vegetable ;,;25/04/2020 \n, Beatrice Newman ;,;$22.4   ;,;egg&milk&vegetable \n;,;

25/04/2020, Andre Norris   ;,;   $28.4   ;,;   \nvegetable;,;   25/04/2020 ,   Albert Lewis ;,;

$23.8;,;   \nbeans&vegetable;,; 25/04/2020,   Javier Bailey   ;,;   \n$24.4   ;,;

beans&vegetable ;,; 25/04/2020   , Everett Lyons ;,;$1.8;,;   beans&vegetable ;,; 25/04/2020 ,

\nAbraham Maxwell;,; $6.8   ;,;tea;,;   25/04/2020   \n,   Traci Craig ;,;$0.6;,; tea&sausage;,;

\n25/04/2020 , Jeffrey Jenkins   ;,;$26.4;,; \ntea&sausage&ham   ;,;   25/04/2020,

Merle Wilson \n;,;   $7.6 ;,; milk;,; 25/04/2020,Janis Franklin   \n;,;$8.7   ;,; milk&beans

;,;25/04/2020 ,  \nLeonard Guerrero ;,;   $1.8   ;,;sausage  \n;,;25/04/2020,Lana Sanchez;,;$14.7

;,; sausage;,;   \n25/04/2020   ,Donna Ball ;,; $28.1  ;,; \nsausage&ham;,;   25/04/2020   ,

Terrell Barber   ;,; \n$9.9   ;,; tea ;,;25/04/2020   ,Kenneth Cunningham;,; \n$16.3 ;,; tea ;,;

25/04/2020,   Daryl Herrera \n;,;$27.5;,; egg;,;   25/04/2020   , Miguel Mcguire;,;$5.2;,; egg&ham

;,;   25/04/2020 ,   \nRogelio Gonzalez;,; $9.5;,;   egg&beans&ham   \n;,;   25/04/2020   ,

Lora Hammond ;,;$20.5 ;,; \ntea;,;   25/04/2020,Owen Ward;,; $21.6   ;,;   \ntea&sausage;,;

25/04/2020,Malcolm Morales ;,;   \n$24.9   ;,;   tea&sausage&beans;,; 25/04/2020 ,   \nEric Mcdaniel

;,;$29.7;,; tea ;,; 25/04/2020 \n,Madeline Estrada;,;   $15.5;,;tea;,;   25/04/2020 \n, Leticia Manning

;,;$15.7 ;,; tea&milk;,; \n25/04/2020 ,   Mario Wallace ;,; $12.3 ;,;tea ;,; \n25/04/2020,Lewis Glover;,;

$13.6   ;,;   \ntea&egg;,;25/04/2020,   Gail Phelps   ;,;$30.5   \n;,; tea&egg&ham   ;,; 25/04/2020 ,

Myrtle Morris \n;,;   $22.6   ;,; tea&egg&ham;,;25/04/2020

'''

# %% [markdown]
# 2. It looks like each transaction is separated from the next transaction by a comma(`,`) and then each piece of data within a transaction is separated by the artifact(`;,;`).
#
#
#
# If we want to split up `daily_sales` into a list of individual transactions, we are going to want to split by comma(`,`) but first, we need to replace the artifact(`;,;`) to something without a comma(`,`), so we don’t split any transactions themselves.
#
#
#
# Replace all the instances of `;,;` in `daily_sales` with some other character (for example, `|` or `*` or `^`) and save the result to `daily_sales_replaced`.

# %%
# Type your code below
daily_sales_replaced=daily_sales.replace(";,;","|")
# daily_sales_replaced=daily_sales_replaced.replace("\n","")
print(daily_sales_replaced)
# Out:
# Jaime Buchanan   |$1.2   |   egg |
# 25/04/2020   ,
#
# Herbert Tran   |   $7.2|
# egg&ham|   25/04/2020 ,
#
# Paul Clarke |$12.5
# |   egg&ham |  25/04/2020 ,
#
#
#
# Lucille Caldwell
# |   $5.1   | egg   | 25/04/2020,
# Eduardo George
#
# |$20.3| egg&sausage
# |25/04/2020   ,   Danny Mclaughlin|$30.8|
#
#
# milk |25/04/2020 ,Stacy Vargas| $1.8   |
# milk&sausage |25/04/2020,
#
# Shaun Brock|
# $17.9|milk&sausage | 25/04/2020 ,
# Erick Harper |$17.4|
#
# ham | 25/04/2020,
# Michelle Howell |$28.5| ham|   25/04/2020
#
# ,
# Carroll Boyd| $14.5|   milk&ham   |
# 25/04/2020   , Teresa Carter
#
# | $19.6 |
# egg|25/04/2020   ,   Jacob Kennedy | $11.4
# | egg&vegetable
#
# | 25/04/2020, Craig Chambers|
# $8.7 | egg&ham&vegetable   |25/04/2020
#
# , Peggy Bell| $8.6 |ham   | 25/04/2020,   Kenneth Cunningham |   $10.5|
#
# tea&ham   |
# 25/04/2020   ,   Marvin Morgan|   $16.4|
# tea&ham&vegetable
#
# |   25/04/2020 ,Herbert Tran
# | $6.5 |   tea&ham&vegetable|
#
# 25/04/2020 ,
# ...

# %% [markdown]
# 3.  Now we can split the string into a list of each individual transaction.
#
#
#
# Split `daily_sales_replaced` around commas and save it to a new list `daily_transactions`.

# %%
# Type your code below
daily_transactions=daily_sales_replaced.split(",")
print(daily_transactions)
# Out:
# ['\n\nJaime Buchanan   |$1.2   |   egg | \n25/04/2020   ', '\n\nHerbert Tran   |   $7.2| \negg&ham|   25/04/2020 ', '\n\nPaul Clarke |$12.5 \n|   egg&ham |  25/04/2020 ', '\n\n\n\nLucille Caldwell   \n|   $5.1   | egg   | 25/04/2020', '\nEduardo George\n\n|$20.3| egg&sausage \n|25/04/2020   ', '   Danny Mclaughlin|$30.8|\n\n\nmilk |25/04/2020 ', 'Stacy Vargas| $1.8   | \nmilk&sausage |25/04/2020', '\n\nShaun Brock| \n$17.9|milk&sausage | 25/04/2020 ', ' \nErick Harper |$17.4|\n\nham | 25/04/2020', ' \nMichelle Howell |$28.5| ham|   25/04/2020\n\n', ' \nCarroll Boyd| $14.5|   milk&ham   |   \n25/04/2020   ', ' Teresa Carter\n\n| $19.6 | \negg|25/04/2020   ', '   Jacob Kennedy | $11.4   \n| egg&vegetable\n\n| 25/04/2020', ' Craig Chambers| \n$8.7 | egg&ham&vegetable   |25/04/2020\n\n', ' Peggy Bell| $8.6 |ham   | 25/04/2020', '   Kenneth Cunningham |   $10.5|\n\ntea&ham   | \n25/04/2020   ', '   Marvin Morgan|   $16.4| \ntea&ham&vegetable\n\n|   25/04/2020 ', 'Herbert Tran \n| $6.5 |  
# ...

# %% [markdown]
# 4.  Our next step is to split each individual transaction into a list of its data points.
#
#     - First, define an empty list `daily_transactions_split`
#
#     - Now, iterate through `daily_transactions` (remember, this is a list of strings currently), and for each transaction, split the string around whatever character you replaced the `;,;` artifacts with in Step 2.
#
#     - Append each of these split strings (which are lists now) to our new list `daily_transactions_split`.

# %%
# Type your code below
daily_transaction_split=[]
for single_transaction in daily_transactions:
    single_transaction_split=single_transaction.split("|")
    daily_transaction_split.append(single_transaction_split)

print(daily_transaction_split)
# Out:
# [['\n\nJaime Buchanan   ', '$1.2   ', '   egg ', ' \n25/04/2020   '], ['\n\nHerbert Tran   ', '   $7.2', ' \negg&ham', '   25/04/2020 '], ['\n\nPaul Clarke ', '$12.5 \n', '   egg&ham ', '  25/04/2020 '], ['\n\n\n\nLucille Caldwell   \n', '   $5.1   ', ' egg   ', ' 25/04/2020'], ['\nEduardo George\n\n', '$20.3', ' egg&sausage \n', '25/04/2020   '], ['   Danny Mclaughlin', '$30.8', '\n\n\nmilk ', '25/04/2020 '], ['Stacy Vargas', ' $1.8   ', ' \nmilk&sausage ', '25/04/2020'], ['\n\nShaun Brock', ' \n$17.9', 'milk&sausage ', ' 25/04/2020 '], [' \nErick Harper ', '$17.4', '\n\nham ', ' 25/04/2020'], [' \nMichelle Howell ', '$28.5', ' ham', '   25/04/2020\n\n'], [' \nCarroll Boyd', ' $14.5', '   milk&ham   ', '   \n25/04/2020   '], [' Teresa Carter\n\n', ' $19.6 ', ' \negg', '25/04/2020   '], ['   Jacob Kennedy ', ' $11.4   \n', ' egg&vegetable\n\n', ' 25/04/2020'], [' Craig Chambers', ' \n$8.7 ', ' egg&ham&vegetable   ', '25/04/2020\n\n'], [' Peggy Bell', ' $8.6 ', 'ham   ', ' 25/04/2020'
# ...

# %% [markdown]
# 5. It looks like each data item has inconsistent whitespace around it. First, define an empty list `transactions_clean`.
#
#
#
# Now, Iterate through `daily_transactions_split` and for each transaction iterate through the different data points and strip off any whitespace.
#
#
#
# Add each of these cleaned up transactions to the new list `transactions_clean`.

# %%
# Type your code below
transactions_clean=[]
for item in daily_transaction_split:
    temp_list=[]
    for subitem in item:
        subitem=subitem.strip()
        temp_list.append(subitem)
    transactions_clean.append(temp_list)

print(transactions_clean)
# Out:
# [['Jaime Buchanan', '$1.2', 'egg', '25/04/2020'], ['Herbert Tran', '$7.2', 'egg&ham', '25/04/2020'], ['Paul Clarke', '$12.5', 'egg&ham', '25/04/2020'], ['Lucille Caldwell', '$5.1', 'egg', '25/04/2020'], ['Eduardo George', '$20.3', 'egg&sausage', '25/04/2020'], ['Danny Mclaughlin', '$30.8', 'milk', '25/04/2020'], ['Stacy Vargas', '$1.8', 'milk&sausage', '25/04/2020'], ['Shaun Brock', '$17.9', 'milk&sausage', '25/04/2020'], ['Erick Harper', '$17.4', 'ham', '25/04/2020'], ['Michelle Howell', '$28.5', 'ham', '25/04/2020'], ['Carroll Boyd', '$14.5', 'milk&ham', '25/04/2020'], ['Teresa Carter', '$19.6', 'egg', '25/04/2020'], ['Jacob Kennedy', '$11.4', 'egg&vegetable', '25/04/2020'], ['Craig Chambers', '$8.7', 'egg&ham&vegetable', '25/04/2020'], ['Peggy Bell', '$8.6', 'ham', '25/04/2020'], ['Kenneth Cunningham', '$10.5', 'tea&ham', '25/04/2020'], ['Marvin Morgan', '$16.4', 'tea&ham&vegetable', '25/04/2020'], ['Herbert Tran', '$6.5', 'tea&ham&vegetable', '25/04/2020'], ['Israel Cummings', '$
# ...

# %% [markdown]
# 6. The cashier wants to get a list of all customer.  Create a list of customer that do not have duplication.
#
#
#
# How many are there?

# %%
# Type your code below
customer_list=[trans[0] for trans in transactions_clean]
print(customer_list)
print("number of customers BEFORE modification: ",len(customer_list))
customer_list=list(set(customer_list))
print(customer_list)
print("number of customers AFTER modification: ",len(customer_list))
# Out:
# ['Jaime Buchanan', 'Herbert Tran', 'Paul Clarke', 'Lucille Caldwell', 'Eduardo George', 'Danny Mclaughlin', 'Stacy Vargas', 'Shaun Brock', 'Erick Harper', 'Michelle Howell', 'Carroll Boyd', 'Teresa Carter', 'Jacob Kennedy', 'Craig Chambers', 'Peggy Bell', 'Kenneth Cunningham', 'Marvin Morgan', 'Herbert Tran', 'Israel Cummings', 'June Doyle', 'Jaime Buchanan', 'Rhonda Farmer', 'Darren Mckenzie', 'Rufus Malone', 'Hubert Miles', 'Joseph Bridges', 'Ernesto Hunt', 'Audrey Ferguson', 'Edna Williams', 'Randy Fleming', 'Elisa Hart', 'Ernesto Hunt', 'Shannon Chavez', 'Sammy Cain', 'Steven Reeves', 'Ruben Jones', 'Gail Phelps', 'Rene Hardy', 'Lucy Snyder', 'Dallas Obrien', 'Stacey Payne', 'Tanya Cox', 'Melody Moran', 'Kenneth Cunningham', 'Ryan Webster', 'Justin Blake', 'Beverly Baldwin', 'Dale Brady', 'Guadalupe Potter', 'Desiree Butler', 'Sonja Barnett', 'Angelica Garza', 'Jamie Welch', 'Rex Hudson', 'Nadine Gibbs', 'Hannah Pratt', 'Gayle Richards', 'Stanley Holland', 'Anna Dean', 'Ernesto H
# ...

# %% [markdown]
# 7.  Now he want to know how much tips he get in the day.
#
#
#
# Consider the list `sales`. It is a list of strings that we want to sum. In order for us to sum these values, we will have to remove the $, and set them equal to floats.

# %%
# Type your code below
tips_list=[float(trans[1].replace("$","")) for trans in transactions_clean]
print(tips_list)
tips_total=sum(tips_list)
print(f"the total amount of tips is {tips_total:.2f}")
# Out:
# [1.2, 7.2, 12.5, 5.1, 20.3, 30.8, 1.8, 17.9, 17.4, 28.5, 14.5, 19.6, 11.4, 8.7, 8.6, 10.5, 16.4, 6.5, 11.8, 22.2, 8.3, 2.9, 22.9, 4.7, 3.5, 5.6, 17.5, 5.5, 17.1, 21.1, 0.3, 13.91, 19.2, 5.4, 5.5, 14.5, 7.3, 20.2, 8.6, 8.3, 15.7, 6.7, 30.8, 12.3, 2.9, 22.4, 6.6, 6.2, 21.1, 2.1, 14.2, 11.6, 25.2, 8.2, 30.8, 22.6, 22.19, 7.4, 5.4, 23.7, 26.6, 25.9, 19.5, 15.6, 23.5, 29.3, 26.4, 17.2, 8.4, 13.1, 20.3, 14.7, 22.4, 28.4, 23.8, 24.4, 1.8, 6.8, 0.6, 26.4, 7.6, 8.7, 1.8, 14.7, 28.1, 9.9, 16.3, 27.5, 5.2, 9.5, 20.5, 21.6, 24.9, 29.7, 15.5, 15.7, 12.3, 13.6, 30.5, 22.6]
# the total amount of tips is 1494.60
